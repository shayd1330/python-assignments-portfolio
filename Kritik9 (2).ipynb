# %%
#import libraries
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

#defining x and y as symbols
x, y = sp.symbols('x y')

# %%
#define the function f(x, y)
f= ((np.e**x)*(sp.sin(y)) + y**3)

#computing first partial derivatives
df_dx=sp.diff(f, x) 

df_dy=sp.diff(f, y) 

#printing first aprtial derivatives
print("The first partial derivative with respect to x is: ", df_dx)
print("The first partial derivative with respect to y is: ", df_dy)
# Out:
# The first partial derivative with respect to x is:  1.0*2.71828182845905**x*sin(y)
# The first partial derivative with respect to y is:  2.71828182845905**x*cos(y) + 3*y**2

# %%
#define variables
x=1
y=-1

#define function
def g(x, y):
    return(((x**2)*(y)) + ((x)*(y**2)))

#defining gradient vector x and y components
grad_vector_x=((2*x)/(x**2 + y**2))

grad_vector_y=((2*y)/(x**2 + y**2))

#printing the gradient vector
print("The gradient vector is: ", (grad_vector_x, grad_vector_y))

#determining the gradient magnitude and printing the value
grad_magnitude= sp.sqrt((grad_vector_x**2) + (grad_vector_y**2))

print("The gradient magnitude is: ", (grad_magnitude))
# Out:
# The gradient vector is:  (1.0, -1.0)
# The gradient magnitude is:  1.41421356237310

# %%
#computing the second partial derivatives of the function h(x, y) = ln(x**2 + y**2)

h=sp.ln(x**2 + y**2) #define function

#second partial deivatives
d2h_dx2=sp.diff(sp.diff(h, x), x) 
d2h_dy2=sp.diff(sp.diff(h, y), y)
d2h_dxdy=sp.diff(sp.diff(h, y), y) 

#printing values
print("The second partial derivative with respect to x is: ", d2h_dx2)
print("The second partial derivative with respect to y is: ", d2h_dy2)
print("The second partial derivative with respect to x and y is: ", d2h_dxdy)
print("Mixed partial derivaties are typically symmetrical, as the d2f/dydx is eqivalent to d2f/dxdy")
# Out:
# The second partial derivative with respect to x is:  -4*x**2/(x**2 + y**2)**2 + 2/(x**2 + y**2)
# The second partial derivative with respect to y is:  -4*y**2/(x**2 + y**2)**2 + 2/(x**2 + y**2)
# The second partial derivative with respect to x and y is:  -4*y**2/(x**2 + y**2)**2 + 2/(x**2 + y**2)
# Mixed partial derivaties are typically symmetrical, as the d2f/dydx is eqivalent to d2f/dxdy

# %%
#creating a contour plot of the function j(x, y) = x***3 − 3*x*y + y**3

#define the function using SymPy
x, y = sp.symbols('x y')
j = x**3 - 3*x*y + y**3

#converting the SymPy expression into a numerical function
j_func = sp.lambdify((x, y), j, 'numpy')

#create a grid of x and y values and evaluate j on this grid
x_vals = np.linspace(-3, 3, 400)
y_vals = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x_vals, y_vals)
Z = j_func(X, Y)

#contour plot of the function j(x, y)
plt.contourf(X, Y, Z, levels=50, cmap='viridis')
plt.colorbar()
plt.title('Contour plot of $j(x, y) = x^3 - 3xy + y^3$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %%
#creating a contour plot of the function n(x, y) = x**3 − 3*x*y + y**3

#import libraries to plot the function n(x, y)
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

#define the function using SymPy
x, y = sp.symbols('x y')
n = (sp.sin(x))*(sp.cos(y))

#converting the SymPy expression into a numerical function
n_func = sp.lambdify((x, y), n, 'numpy')

#create a grid of x and y values and evaluate n on this grid
x_vals = np.linspace(-3, 3, 400)
y_vals = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x_vals, y_vals)
Z = n_func(X, Y)

#contour plot of the function ?
plt.contourf(X, Y, Z, levels=50, cmap='viridis')
plt.colorbar()
#plt.title('Contour plot of $n(x, y) = cos(x)*sin(x)')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

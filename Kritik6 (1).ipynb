# %%
import numpy as np 
import matplotlib.pyplot as plt
import math


def normal_density(mean, varience, x): #define function
    density_function=((1)/(np.sqrt((2)*(np.pi)*((varience)**2))))*(math.exp((-(x-mean)**2)/((2)*((varience)**2))))
    return density_function

def normal_density_graph(mean, varience, range_x): 
    x_vals=np.linspace(*range_x, 500)
    y_vals=[normal_density(mean, varience, x) for x in x_vals]
    #plot the normal density function graph
    plt.plot(x_vals, y_vals) 

#example 1
normal_density_graph(4, 9, (-11, 11))

#example 2
normal_density_graph(85, 7, (-15, 15))

#components of graph
plt.title('Normal Density Function') #title of graph
plt.show() #display graph


#utilizing trapezodial rule of numerical integration to integrate the function and calculating the probability of male height being between 162cm and 190cm

point_range=500
varience=7.1 #height varience
mean=171 #the mean heigh(cm)
a=162 #previded height restriction 1
b=190 #provided height restriction 2
def numerical_integration(mean, varience, a, b, point_range):
    x_vals=np.linspace(a, b, point_range)
    trapezodial_rule= ((b-a)/(point_range - 1))*(np.sum(normal_density(mean, varience, point_range)))
    return trapezodial_rule

print(numerical_integration(mean, varience, a, b, point_range))
# Out:
# 0.0
